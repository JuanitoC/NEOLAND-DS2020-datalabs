# %% [markdown]
# Adquisición de datos en Python - PRA02
# --------------------------------------
#
#
# En este Notebook encontraréis dos conjuntos de ejercicios: un primer conjunto de **ejercicios para practicar** y un segundo conjunto de **actividades evaluables** como PRÁCTICAS de la asignatura.

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Hemos visto el uso de la libería [Requests](http://docs.python-requests.org/) para realizar peticiones a web API de manera manual.
#
# Mediante esta librería podemos realizar solicitudes como en el ejemplo que hemos visto de [postcodes.io](http://postcodes.io).
#
# `response = requests.get('http://api.postcodes.io/postcodes/E98%201TT')`
#
#
#
#
# Hemos visto que, en realizar una petición a una web API http, recuperamos un objeto que contiene, entre otros, los siguientes atributos: **status.code**, **content** y **headers**. Busca la información sobre los códigos de **status.code** y completa la siguiente tabla sobre los códigos de error http.

# %% [markdown]
# **Respuesta**
#
# Descripción de los principales códigos de error http:
#
# * 200: OK. Conexión > realizada
# * 301: Moved Permanently > Hay que lanzar la petición a una web que te facilitan
# * 400: Bad Request > El servidor no procesa la solicitud por algún error
# * 401: Unauthorized > La autentificación es posible pero ha fallado
# * 403: Forbidden > No tienes los accesos para conectarte
# * 404: Not Found > La web no se encuentra o no existe
# * 505: HTTP Version Not Supported > El servidor no soporta la versión del protocolo HTTP que esta utilizando el navegador
# * 501: Not Implemented > El servidor no soporta alguna funcionalidad

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# En este ejercicio intentaremos hacer una solicitud a tres paginas web diferentes vía el protocolo http mediante el método GET implementado en `requests.get`.
#
# Obtén mediante `requests.get`, el contenido y el correspondiente `status.code` de las siguentes pàginas web:
#
# - http://google.com
# - http://wikipedia.org
# - https://mikemai.net/
# - http://google.com/noexisto
#
# Para cada web, muestra:
#
# - Los primeros 80 carácteres del contenido de la web
# - El código de `status.code`.

# %%
# Importo las librerías necesarias
import requests
import urllib.request

# %%
# Google
# Extraigo el status y lo imprimo
print(
    requests.get('http://google.com')
    )
# Extraigo los primeros 80 caracteres y los imprimo
print(
    urllib.request.urlopen('http://google.com').read()[:80]
    )
# Out:
# <Response [200]>
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="es"'

# %%
# Wikipedia
# Extraigo el status y lo imprimo
print(
    requests.get('http://wikipedia.org')
    )
# Extraigo los primeros 80 caracteres y los imprimo
print(
    urllib.request.urlopen('http://wikipedia.org').read()[:80]
    )
# Out:
# <Response [200]>
# b'<!DOCTYPE html>\n<html lang="mul" class="no-js">\n<head>\n<meta charset="utf-8">\n<t'

# %%
# Mikemai
# Extraigo el status y lo imprimo
print(
    requests.get('https://mikemai.net/')
    )
# Como obtengo un error 406 no puedo extraer los primeros 80 caracteres
# Out:
# <Response [406]>

# %%
# google.com/no.existo
# Extraigo el status y lo imprimo
print(
    requests.get('http://google.com/noexisto')
    )
# Como obtengo un error 404 no puedo extraer los primeros 80 caracteres
# Out:
# <Response [404]>

# %% [markdown]
# ### Ejercicio 3
#
# En este ejercicio vamos a hacer un poco de *Fun with cats*. Existe una API para *cat-facts* (hechos sobre gatos) en la base de https://cat-fact.herokuapp.com. Esta API tiene dos puntos de acceso:
#
# - **/facts**
# - **/users**
#
# Según la documentación, el modelo en el punto de entrada de un **fact** es tal y como se indica a continuación:
#
# |    Key    |      Type     |                                              Description                                              |   |   |
# |:---------:|:-------------:|:-----------------------------------------------------------------------------------------------------:|---|---|
# | _id       | ObjectId      | Unique ID for the Fact                                                                                |   |   |
# | _v        | Number        | Version number of the Fact                                                                            |   |   |
# | user      | ObjectId      | ID of the User who added the Fact                                                                     |   |   |
# | text      | String        | The Fact itself                                                                                       |   |   |
# | updatedAt | Timestamp     | Date in which Fact was last modified                                                                  |   |   |
# | sendDate  | Timestamp     | If the Fact is meant for one time use, this is the date that it is used                               |   |   |
# | deleted   | Boolean       | Whether or not the Fact has been deleted (Soft deletes are used)                                      |   |   |
# | source    | String (enum) | Can be 'user' or 'api', indicates who added the fact to the DB                                        |   |   |
# | used      | Boolean       | Whether or not the Fact has been sent by the CatBot. This value is reset each time every Fact is used |   |   |
# | type      | String        | Type of animal the Fact describes (e.g. ‘cat’, ‘dog’, ‘horse’)                                        |   |   |
#
# Así, para obtener el **fact** número *58e0086f0aac31001185ed02*, debemos construir una solicitud a la url:
#
# - *https://cat-fact.herokuapp.com/facts/58e0086f0aac31001185ed02*
#
# El objecto que se nos devolverá, contendrá la información indicada en la tabla en formato *json* serializado.
#
# a) Contruye la solicitud, convierte el resultado a un diccionario y muestra por pantalla el resultado de los valores de la tabla anterior para el fact id *58e0086f0aac31001185ed02*.

# %%
# Respuesta
import pandas as pd

URL1= 'https://cat-fact.herokuapp.com/facts/'
URL2= '58e0086f0aac31001185ed02'
requests.get(URL1+URL2).json()
# Out:
# {'status': {'verified': True, 'sentCount': 1},
#  'type': 'cat',
#  'deleted': False,
#  '_id': '58e0086f0aac31001185ed02',
#  'user': {'name': {'first': 'Kasimir', 'last': 'Schulz'},
#   'photo': 'https://lh6.googleusercontent.com/-BS_rskGd3kA/AAAAAAAAAAI/AAAAAAAAADg/yAxrX9QabMg/photo.jpg?sz=200',
#   '_id': '58e007480aac31001185ecef'},
#  'text': "Cats can't taste sweetness.",
#  '__v': 0,
#  'source': 'https://www.scientificamerican.com/article/strange-but-true-cats-cannot-taste-sweets/',
#  'updatedAt': '2020-08-29T20:20:03.172Z',
#  'createdAt': '2018-03-16T20:20:03.622Z',
#  'used': True}

# %% [markdown]
# b) Para los fact ids:
#
# - *5d38bdab0f1c57001592f156*
# - *5ed11e643c15f700172e3856*
# - *5ef556dff61f300017030d4c*
# - *5d9d4ae168a764001553b388*
#
# Obtén campos *type*, *user*, *user*, *source*, *used*, *text* y imprímelos siguiendo el siguiente formato:
#
#
# `Type: cat	User: 58e007480aac31001185ecef
# Used: True	Id: 58e0086f0aac31001185ed02
# Source: https://www.scientificamerican.com/article/strange-but-true-cats-cannot-taste-sweets/
# Text: Cats can't taste sweetness.`

# %%
# Respuesta: 5d38bdab0f1c57001592f156

URL2= '5d38bdab0f1c57001592f156'
CATS=requests.get(URL1+URL2).json()
print('Type: '+str(CATS['type'])+' User: '+str(CATS['user']['_id']))
print('Used: '+str(CATS['used'])+ ' Id: '+str(CATS['_id']))
print('Source: '+str(CATS['source']))
print('Text: '+str(CATS['text']))
# Out:
# Type: cat User: 5a9ac18c7478810ea6c06381
# Used: False Id: 5d38bdab0f1c57001592f156
# Source: user
# Text: While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.

# %%
# Respuesta: 5ed11e643c15f700172e3856

URL2= '5ed11e643c15f700172e3856'
CATS=requests.get(URL1+URL2).json()
print('Type: '+str(CATS['type'])+' User: '+str(CATS['user']['_id']))
print('Used: '+str(CATS['used'])+ ' Id: '+str(CATS['_id']))
print('Source: '+str(CATS['source']))
print('Text: '+str(CATS['text']))
# Out:
# Type: cat User: 5ed11e353c15f700172e3855
# Used: False Id: 5ed11e643c15f700172e3856
# Source: user
# Text: Los gatos tienen más huesos que los seres humanos, nos ganan por 24.

# %%
# Respuesta: 5ef556dff61f300017030d4c

URL2= '5ef556dff61f300017030d4c'
CATS=requests.get(URL1+URL2).json()
print('Type: '+str(CATS['type'])+' User: '+str(CATS['user']['_id']))
print('Used: '+str(CATS['used'])+ ' Id: '+str(CATS['_id']))
print('Source: '+str(CATS['source']))
print('Text: '+str(CATS['text']))
# Out:
# Type: cat User: 5e1a9b981fd6150015fa736f
# Used: False Id: 5ef556dff61f300017030d4c
# Source: user
# Text: Lucy, the oldest cat ever, lived to be 39 years old which is equivalent to 172 cat years.

# %%
# Respuesta: 5d9d4ae168a764001553b388

URL2= '5d9d4ae168a764001553b388'
CATS=requests.get(URL1+URL2).json()
print('Type: '+str(CATS['type'])+' User: '+str(CATS['user']['_id']))
print('Used: '+str(CATS['used'])+ ' Id: '+str(CATS['_id']))
print('Source: '+str(CATS['source']))
print('Text: '+str(CATS['text']))
# Out:
# Type: cat User: 5d9d4a4468a764001553b387
# Used: False Id: 5d9d4ae168a764001553b388
# Source: user
# Text: Cats conserve energy by sleeping for an average of 13 to 14 hours a day.

# %% [markdown]
# ## Ejercicio 4
#
# En los ejercicios anteriores, usamos directamente una API para hacer la solicitud que requiramos, y nos encargamos directamente de la gestión de los datos de salida.
#
# No obstante, hemos visto ya el uso de librerías que facilitan el accesso a una API. La mayoría de estas librerías (y APIs de proyectos populares) requieren de un registro en la web de desarolladores.
#
#
# Sigue la documentación proporcionada en clase para conseguir un registro en el panel de desarolladores de Twitter. Obtendrás 4 códigos para autenticar tu aplicación.
#
# Usa la librería **tweepy** para programar dos funciones.
#
# - La primera función, se autentica en la API de twitter usando los 4 códigos proporcionados por el registro. A partir de un nombre de usuario en twitter proporcionado en el argumento de la función, esta retorna una tupla `(user, api)` con el objeto `twepy.models.User`, correspondiente a ese usuario y el descriptor de la API ya inicializada.
# - La segunda funcion, aceptará un objeto  `twepy.models.User` de entrada y imprimirá:
#  1. El número de tweets del usuario.
#  1. El número de amigos del usuario.
#  1. El número de seguidores del usuario.
#  1. Los nombres de pantalla de los primeros 10 amigos del usuario (`screen_name`), sus nombres (`name`) junto con sus descripciones.
#
# Ejecuta las dos funciones sobre el usuario de twitter **Space_Station**.

# %%
# Respuesta Función 1
import tweepy
import requests
import sys, os

def funcion_1(TwitterUser):
    
    # Carga de claves
    tw_creeds = open("Twitter_creds.txt", "r")
    lines = tw_creeds.readlines()
    keys= []
    for l in lines:
        keys.append(l.split("=")[1].splitlines(False)[0])      
    CONSUMER_KEY = keys[0]
    CONSUMER_SECRET = keys[1]
    ACCESS_TOKEN = keys[2]
    ACCESS_TOKEN_SECRET = keys[3]
    
    # Interactuamos con la API de Twitter
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    
    # Lanzamos la api
    api = tweepy.API(auth)
        #obtenemos los datos del usuario
    # Obtenemos datos del usuario "Space Station" usando la librería tweepy
    user = tweepy.API(auth).search_users(str(TwitterUser))
    return (user[0]._api,user[0].name)
 
        
# Ejecuto la funcion_1!        
funcion_1('Space_Station')
# Out:
# (<tweepy.api.API at 0xfb82fe8>, 'International Space Station')

# %%
# Respuesta: Funcion_2

import tweepy
import requests
import sys, os

def funcion_2(TwitterUser):
    
    # Carga de claves
    tw_creeds = open("Twitter_creds.txt", "r")
    lines = tw_creeds.readlines()
    keys= []
    for l in lines:
        keys.append(l.split("=")[1].splitlines(False)[0])  
        
    CONSUMER_KEY = keys[0]
    CONSUMER_SECRET = keys[1]
    ACCESS_TOKEN = keys[2]
    ACCESS_TOKEN_SECRET = keys[3]
    
    # Interactuamos con la API de Twitter
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    
    # Lanzamos la api
    api = tweepy.API(auth)
        #obtenemos los datos del usuario
    # Obtenemos datos del usuario "Space Station" usando la librería tweepy
    user = tweepy.API(auth).search_users(str(TwitterUser))
    # Saco número de tweets, de amigos y de seguidores
    Tw = user[0].listed_count
    Fr = user[0].friends_count
    Fl = user[0].followers_count
    print('El usuario {} ha publicado {} tweets. \nEl usuario {} tiene {} amigos. \nEl usuario {} tiene seguidores.'.format(TwitterUser,Tw,TwitterUser,Fr,TwitterUser,Fl))
    # 10 primeros amigos: nombre y descripcion
    Fr10 = tweepy.API(auth).friends(TwitterUser)[0:10]
    # Mediante un for extraigo e imprimo los datos
    for Fr in Fr10:
        print("Usuario: {} Descripción: {} \n".format(Fr.name, Fr.description))


# Ejecuto la funcion_!        
funcion_2('Space_Station')
# Out:
# El usuario Space_Station ha publicado 12746 tweets.
# El usuario Space_Station tiene 219 amigos.
# El usuario Space_Station tiene seguidores.
# Usuario: Zebulon Scoville Descripción: 86th NASA Flight Director. Lucky husband and father. Always looking for a challenge. Tweets are my own, so don't blame NASA.
#
# Usuario: Stephanie Wilson Descripción:
#
# Usuario: Jim Morhard Descripción: Serving as @NASA's Deputy Administrator, working to support the agency's many missions including space exploration, Earth sciences, and aeronautics.
#
# Usuario: Bob Cabana Descripción: Former astronaut and current Center Director of Kennedy Space Center.
#
# Usuario: Sergey Kud-Sverchkov Descripción: Космонавт Роскосмоса (@Roscosmos) Сергей Кудь-Сверчков
# //
# @Roscosmos cosmonaut Sergey Kud-Sverchkov
#
# Usuario: U.S. Space Command Descripción: The OFFICIAL Twitter Page of United States Space Command, the 11th Combatant Command in the Department of Defense. #USSPACECOM
#
# Usuario: Joshua Kutryk Descripción: Canadian Space Agency Astronaut and RCAF Test Pilot.
#
# Usuario: Ivan Vagner Descripción: Космонавт Роскосмоса (@Roscosmos) Иван Вагнер
# //
# @Roscosmos cosmonaut Ivan Vagner
#
# Usuario: Megan McArthur Descripción: NASA Astronaut and veteran of Space Shuttle mission STS-125.
#
# Usuario: Jasmin Moghbeli Descripción: Marine Attack Helicopter Pilot. Test Pilot. NASA Astronaut. Auntie to some ridiculously cool kids. Excited to share my journey!

# %% [markdown]
# ### Ejercicio 5
#
# [congreso.es](http://www.congreso.es/) es la página web del Congreso de los Diputados en España. En ella se guarda una relación de todos los diputados elegidos en cada una de las legislaturas.
#
# En una de las páginas se puede observar un mapa del hemiciclo, junto con la posición de cada uno de los diputados, su fotografía, su representación territorial y el partido político al que esté adscrito.  Esta url se encuentra en [Hemiciclo](http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados/Hemiciclo).
#
# Usad `scrappy` para extraer la siguiente información:
#
# *Nombre*, *Territorio*, *Partido*, *URL Imagen*, en el formato de un diccionario, como por ejemplo:
#
# `{'Nombre': 'Callejas Cano, Juan Antonio ', 'Territorio': 'Diputado por Ciudad Real', 'Partido': 'G.P. Popular en el Congreso', 'url': '/wc/htdocs/web/img/diputados/peq/35_14.jpg'}`
#
# Para Ello:
#
# - Utilizad el tutorial de scrappy para encontrar un `xpath` que contenga la información requerida
# - Extraed la información requerida en forma de diccionario.
#
# **Nota**: si la ejecución del _crawler_ os devuelve un error `ReactorNotRestartable`, reiniciad el núcleo del Notebook (en el menú: `Kernel` - `Restart`)

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

class Cong_Spider(scrapy.Spider):
    # Nombre de la araña
    name = "Cong_spider"
    # Url de la que extraer la información
    start_urls = ["https://www.congreso.es/web/guest/hemiciclo"] 
    
    # Función de parseo

    def parse (self, response):
        # Indicamos que extraiga toda la informacion de los diputados
        for dip in response.xpath('//map[@name="hemiciclo"]/area/@onmouseover').getall():
            # elimino el texto del principio y los paréntesis de principio y final para así poder convertir en lista
            # la extracción
            dipdatos = dip.replace('javascript:mostrarFotografiaHemiciclo( ','').replace(");","").split(",")
            
            #Creo cada uno de los campos a buscar y les quito `'`
            Nombre = dipdatos[2].replace("'","")+", "+ dipdatos[3].split("(")[0].replace("'","")
            Territorio = dipdatos[4].replace("'","")
            Partido = dipdatos[5].replace("'","")
            Foto  =  dipdatos[0].replace("'","")
            diccionario = {"Nombre":Nombre,"Territorio":Territorio,"Partido":Partido,"Foto":Foto}
        
            print(diccionario,"\n\n")

# %%
# una vez definida la araña con la class ahora lanzamos
if __name__ == "__main__":
    # Creamos un crawler.
    process = CrawlerProcess({
        'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',
        'DOWNLOAD_HANDLERS': {'s3': None},
        'LOG_ENABLED': True
    })
    # Inicializamos el crawler con nuestra araña.
    process.crawl(Cong_Spider)
    # Lanzamos la araña.
    process.start()
# Out:
# 2021-01-11 18:24:03 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-01-11 18:24:03 [scrapy.utils.log] INFO: Versions: lxml 4.6.2.0, libxml2 2.9.5, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.8.5 (tags/v3.8.5:580fbb0, Jul 20 2020, 15:43:08) [MSC v.1926 32 bit (Intel)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1i  8 Dec 2020), cryptography 3.3.1, Platform Windows-10-10.0.19041-SP0
# 2021-01-11 18:24:03 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-01-11 18:24:03 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2021-01-11 18:24:03 [scrapy.extensions.telnet] INFO: Telnet Password: 10cf1bcfb2007bbe
# 2021-01-11 18:24:04 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2021-01-11 18:24:04 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-01-11 18:24:04 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-01-11 18:24:04 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-01-11 18:24:04 [scrapy.core.engine] INFO: Spider opened
# 2021-01-11 18:24:04 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-01-11 18:24:04 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-01-11 18:24:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.congreso.es/web/guest/hemiciclo> (referer: None)
# 2021-01-11 18:24:05 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-01-11 18:24:05 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 254,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 40281,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 1.108327,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 1, 11, 17, 24, 5, 411386),
#  'log_count/DEBUG': 1,
#  'log_count/INFO': 10,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2021, 1, 11, 17, 24, 4, 303059)}
# 2021-01-11 18:24:05 [scrapy.core.engine] INFO: Spider closed (finished)
# {'Nombre': ' Batet Lamaña,  Meritxell ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Mesa del Congreso ', 'Foto': '/docu/imgweb/diputados/215_14.jpg'}
#
#
# {'Nombre': ' Rodríguez Gómez de Celis,  Alfonso ', 'Territorio': 'Diputado por Sevilla', 'Partido': ' G. P. Mesa del Congreso ', 'Foto': '/docu/imgweb/diputados/168_14.jpg'}
#
#
# {'Nombre': ' Pastor Julián,  Ana María ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Mesa del Congreso ', 'Foto': '/docu/imgweb/diputados/31_14.jpg'}
#
#
# {'Nombre': ' Elizo Serrano,  María Gloria ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Mesa del Congreso ', 'Foto': '/docu/imgweb/diputados/300_14.jpg'}
#
#
# {'Nombre': ' Gil Lázaro,  Ignacio ', 'Territorio': 'Diputado por Valencia/València', 'Partido': ' G. P. Mesa del Congreso ', 'Foto': '/docu/imgweb/diputados/295_14.jpg'}
#
#
# {'Nombre': ' Pisarello Prados,  Gerardo ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Mesa del Congreso ', 'Foto': '/docu/imgweb/diputados/290_14.jpg'}
#
#
# {'Nombre': ' Hernanz Costa,  Sofía ', 'Territorio': 'Diputada por Balears (Illes)', 'Partido': ' G. P. Mesa del Congreso ', 'Foto': '/docu/imgweb/diputados/289_14.jpg'}
#
#
# {'Nombre': ' Sánchez Serna,  Javier ', 'Territorio': 'Diputado por Murcia', 'Partido': ' G. P. Mesa del Congreso ', 'Foto': '/docu/imgweb/diputados/67_14.jpg'}
#
#
# {'Nombre': ' Suárez Illana,  Adolfo ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Mesa del Congreso ', 'Foto': '/docu/imgweb/diputados/32_14.jpg'}
#
#
# {'Nombre': ' Sánchez Pérez-Castejón,  Pedro ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/274_14.jpg'}
#
#
# {'Nombre': ' Calvo Poyato,  Carmen ', 'Territorio': ' Relaciones con las Cortes y Memoria Democrática)', 'Partido': 'Diputada por Madrid', 'Foto': '/docu/imgweb/diputados/258_14.jpg'}
#
#
# {'Nombre': ' Iglesias Turrión,  Pablo ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/319_14.jpg'}
#
#
# {'Nombre': ' Montero Cuadrado,  María Jesús ', 'Territorio': 'Diputada por Sevilla', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/225_14.jpg'}
#
#
# {'Nombre': ' Ábalos Meco,  José Luis ', 'Territorio': ' Movilidad y Agenda Urbana)', 'Partido': 'Diputado por Valencia/València', 'Foto': '/docu/imgweb/diputados/267_14.jpg'}
#
#
# {'Nombre': ' Díaz Pérez,  Yolanda ', 'Territorio': 'Diputada por Pontevedra', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/171_14.jpg'}
#
#
# {'Nombre': ' Montero Gil,  Irene María ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/329_14.jpg'}
#
#
# {'Nombre': ' Garzón Espinosa,  Alberto ', 'Territorio': 'Diputado por Málaga', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/12_14.jpg'}
#
#
# {'Nombre': ' Calviño Santamaría,  Nadia María ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/517_14.jpg'}
#
#
# {'Nombre': ' Ribera Rodríguez,  Teresa ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/502_14.jpg'}
#
#
# {'Nombre': ' Campo Moreno,  Juan Carlos ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/518_14.jpg'}
#
#
# {'Nombre': ' Robles Fernández,  Margarita ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/504_14.jpg'}
#
#
# {'Nombre': ' González Laya,  María Aránzazu ', 'Territorio': ' Unión Europea y Cooperación)', 'Partido': 'Diputado por ', 'Foto': '/docu/imgweb/diputados/503_14.jpg'}
#
#
# {'Nombre': ' Grande-Marlaska Gómez,  Fernando ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/509_14.jpg'}
#
#
# {'Nombre': ' Celaá Diéguez,  Isabel ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/510_14.jpg'}
#
#
# {'Nombre': ' Maroto Illera,  Reyes ', 'Territorio': ' Comercio y Turismo)', 'Partido': 'Diputado por ', 'Foto': '/docu/imgweb/diputados/511_14.jpg'}
#
#
# {'Nombre': ' Planas Puchades,  Luis ', 'Territorio': ' Pesca y Alimentación)', 'Partido': 'Diputado por ', 'Foto': '/docu/imgweb/diputados/512_14.jpg'}
#
#
# {'Nombre': ' Darias San Sebastián,  Carolina ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/516_14.jpg'}
#
#
# {'Nombre': ' Rodríguez Uribes,  José Manuel ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/506_14.jpg'}
#
#
# {'Nombre': ' Duque Duque,  Pedro ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/513_14.jpg'}
#
#
# {'Nombre': ' Escrivá Belmonte,  José Luis ', 'Territorio': ' Seguridad Social y Migraciones)', 'Partido': 'Diputado por ', 'Foto': '/docu/imgweb/diputados/508_14.jpg'}
#
#
# {'Nombre': ' Castells Oliván,  Manuel ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/501_14.jpg'}
#
#
# {'Nombre': ' Illa Roca,  Salvador ', 'Territorio': 'Diputado por ', 'Partido': ' G. P.  ', 'Foto': '/docu/imgweb/diputados/507_14.jpg'}
#
#
# {'Nombre': ' Lastra Fernández,  Adriana ', 'Territorio': 'Diputada por Asturias', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/109_14.jpg'}
#
#
# {'Nombre': ' Simancas Simancas,  Rafael ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/287_14.jpg'}
#
#
# {'Nombre': ' Fernández Casero,  Ana Belén ', 'Territorio': 'Diputada por Cáceres', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/230_14.jpg'}
#
#
# {'Nombre': ' Sicilia Alférez,  Felipe Jesús ', 'Territorio': 'Diputado por Jaén', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/259_14.jpg'}
#
#
# {'Nombre': ' Zaragoza Alonso,  José ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/196_14.jpg'}
#
#
# {'Nombre': ' Ros Martínez,  Susana ', 'Territorio': 'Diputada por Castellón/Castelló', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/53_14.jpg'}
#
#
# {'Nombre': ' Meijón Couselo,  Guillermo Antonio ', 'Territorio': 'Diputado por Pontevedra', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/1_14.jpg'}
#
#
# {'Nombre': ' Carcedo Roces,  María Luisa ', 'Territorio': 'Diputada por Asturias', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/270_14.jpg'}
#
#
# {'Nombre': ' Valerio Cordero,  Magdalena ', 'Territorio': 'Diputada por Guadalajara', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/140_14.jpg'}
#
#
# {'Nombre': ' Gómez Hernández,  Héctor ', 'Territorio': 'Diputado por S/C Tenerife', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/104_14.jpg'}
#
#
# {'Nombre': ' Cerdán León,  Santos ', 'Territorio': 'Diputado por Navarra', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/163_14.jpg'}
#
#
# {'Nombre': ' Martínez Seijo,  María Luz ', 'Territorio': 'Diputada por Palencia', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/251_14.jpg'}
#
#
# {'Nombre': ' Leal Fernández,  Isaura ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/352_14.jpg'}
#
#
# {'Nombre': ' Sumelzo Jordán,  Susana ', 'Territorio': 'Diputada por Zaragoza', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/126_14.jpg'}
#
#
# {'Nombre': ' Elorza González,  Odón ', 'Territorio': 'Diputado por Gipuzkoa', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/324_14.jpg'}
#
#
# {'Nombre': ' González Ramos,  Manuel Gabriel ', 'Territorio': 'Diputado por Albacete', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/147_14.jpg'}
#
#
# {'Nombre': ' Rodríguez Salas,  José Antonio ', 'Territorio': 'Diputado por Granada', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/6_14.jpg'}
#
#
# {'Nombre': ' Soler Mur,  Alejandro ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/144_14.jpg'}
#
#
# {'Nombre': ' Faneca López,  María Luisa ', 'Territorio': 'Diputada por Huelva', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/253_14.jpg'}
#
#
# {'Nombre': ' Cancela Rodríguez,  Pilar ', 'Territorio': 'Diputada por Coruña (A)', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/292_14.jpg'}
#
#
# {'Nombre': ' López Cano,  Ignacio ', 'Territorio': 'Diputado por Málaga', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/343_14.jpg'}
#
#
# {'Nombre': ' Gutiérrez Prieto,  Sergio ', 'Territorio': 'Diputado por Toledo', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/180_14.jpg'}
#
#
# {'Nombre': ' López Álvarez,  Patxi ', 'Territorio': 'Diputado por Bizkaia', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/61_14.jpg'}
#
#
# {'Nombre': ' Casares Hontañón,  Pedro ', 'Territorio': 'Diputado por Cantabria', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/347_14.jpg'}
#
#
# {'Nombre': ' Diouf Dioh,  Luc Andre ', 'Territorio': 'Diputado por Palmas (Las)', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/221_14.jpg'}
#
#
# {'Nombre': ' Anguita Pérez,  Omar ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/354_14.jpg'}
#
#
# {'Nombre': ' Berja Vega,  Laura ', 'Territorio': 'Diputada por Jaén', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/70_14.jpg'}
#
#
# {'Nombre': ' Taibo Monelos,  Diego ', 'Territorio': 'Diputado por Coruña (A)', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/373_14.jpg'}
#
#
# {'Nombre': ' Cantera de Castro,  Zaida ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/38_14.jpg'}
#
#
# {'Nombre': ' Blanquer Alcaraz,  Patricia ', 'Territorio': 'Diputada por Alicante/Alacant', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/71_14.jpg'}
#
#
# {'Nombre': ' Serrada Pariente,  David ', 'Territorio': 'Diputado por Salamanca', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/37_14.jpg'}
#
#
# {'Nombre': ' Ruiz i Carbonell,  Joan ', 'Territorio': 'Diputado por Tarragona', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/209_14.jpg'}
#
#
# {'Nombre': ' Zamarrón Moreno,  Agustín ', 'Territorio': 'Diputado por Burgos', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/19_14.jpg'}
#
#
# {'Nombre': ' Nasarre Oliva,  Begoña ', 'Territorio': 'Diputada por Huesca', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/313_14.jpg'}
#
#
# {'Nombre': ' Carrillo de los Reyes,  Beatriz Micaela ', 'Territorio': 'Diputada por Sevilla', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/280_14.jpg'}
#
#
# {'Nombre': ' Botella Gómez,  Ana María ', 'Territorio': 'Diputada por Valencia/València', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/238_14.jpg'}
#
#
# {'Nombre': ' Marí Klose,  Pau ', 'Territorio': 'Diputado por Zaragoza', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/73_14.jpg'}
#
#
# {'Nombre': ' Fagúndez Campo,  Antidio ', 'Territorio': 'Diputado por Zamora', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/4_14.jpg'}
#
#
# {'Nombre': ' Caballero Gutiérrez,  Helena ', 'Territorio': 'Diputada por Valladolid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/320_14.jpg'}
#
#
# {'Nombre': ' Alfonso Cendón,  Javier ', 'Territorio': 'Diputado por León', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/103_14.jpg'}
#
#
# {'Nombre': ' García Gómez,  Valentín ', 'Territorio': 'Diputado por Badajoz', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/226_14.jpg'}
#
#
# {'Nombre': ' Andrés Barea,  Josefa ', 'Territorio': 'Diputada por Valencia/València', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/66_14.jpg'}
#
#
# {'Nombre': ' Aceves Galindo,  José Luis ', 'Territorio': 'Diputado por Segovia', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/56_14.jpg'}
#
#
# {'Nombre': ' Bueno Campanario,  Eva Patricia ', 'Territorio': 'Diputada por Sevilla', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/314_14.jpg'}
#
#
# {'Nombre': ' Peña Camarero,  Esther ', 'Territorio': 'Diputada por Burgos', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/18_14.jpg'}
#
#
# {'Nombre': ' Renau Martínez,  Germán ', 'Territorio': 'Diputado por Castellón/Castelló', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/52_14.jpg'}
#
#
# {'Nombre': ' Ramos Esteban,  César Joaquín ', 'Territorio': 'Diputado por Cáceres', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/178_14.jpg'}
#
#
# {'Nombre': ' Mínguez García,  Montse ', 'Territorio': 'Diputada por Lleida', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/199_14.jpg'}
#
#
# {'Nombre': ' Lamuà Estañol,  Marc ', 'Territorio': 'Diputado por Girona', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/200_14.jpg'}
#
#
# {'Nombre': ' Prieto Nieto,  Ana ', 'Territorio': 'Diputada por Lugo', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/81_14.jpg'}
#
#
# {'Nombre': ' Guerra López,  Sonia ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/357_14.jpg'}
#
#
# {'Nombre': ' Sahuquillo García,  Luis Carlos ', 'Territorio': 'Diputado por Cuenca', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/2_14.jpg'}
#
#
# {'Nombre': ' Guijarro Ceballos,  María ', 'Territorio': 'Diputada por Bizkaia', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/136_14.jpg'}
#
#
# {'Nombre': ' Sánchez Jódar,  Marisol ', 'Territorio': 'Diputada por Murcia', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/276_14.jpg'}
#
#
# {'Nombre': ' Baños Ruiz,  Carmen ', 'Territorio': 'Diputada por Murcia', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/365_14.jpg'}
#
#
# {'Nombre': ' García Morís,  Roberto ', 'Territorio': 'Diputado por Asturias', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/231_14.jpg'}
#
#
# {'Nombre': ' Alonso Suárez,  María Olga ', 'Territorio': 'Diputada por Pontevedra', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/72_14.jpg'}
#
#
# {'Nombre': ' Bravo Barco,  Eva ', 'Territorio': 'Diputada por Cádiz', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/281_14.jpg'}
#
#
# {'Nombre': ' Sancho Guardia,  Alfredo ', 'Territorio': 'Diputado por Huesca', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/312_14.jpg'}
#
#
# {'Nombre': ' Pérez Abellás,  Adolfo ', 'Territorio': 'Diputado por Ourense', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/33_14.jpg'}
#
#
# {'Nombre': ' Soto Burillo,  Juan Luis ', 'Territorio': 'Diputado por Murcia', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/275_14.jpg'}
#
#
# {'Nombre': ' Marra Domínguez,  María Ángeles ', 'Territorio': 'Diputada por Pontevedra', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/46_14.jpg'}
#
#
# {'Nombre': ' Navalpotro Gómez,  Julio ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/366_14.jpg'}
#
#
# {'Nombre': ' Vicente Viondi,  Daniel ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/80_14.jpg'}
#
#
# {'Nombre': ' Gutiérrez Salinas,  Indalecio ', 'Territorio': 'Diputado por Almería', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/358_14.jpg'}
#
#
# {'Nombre': ' Crespín Rubio,  Rafaela ', 'Territorio': 'Diputada por Córdoba', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/107_14.jpg'}
#
#
# {'Nombre': ' Serrano Martínez,  Juan Francisco ', 'Territorio': 'Diputado por Jaén', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/158_14.jpg'}
#
#
# {'Nombre': ' Baldoví Roda,  Joan ', 'Territorio': 'Diputado por Valencia/València', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/247_14.jpg'}
#
#
# {'Nombre': ' Sabanés Nadal,  Inés ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/234_14.jpg'}
#
#
# {'Nombre': ' Errejón Galván,  Íñigo ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/233_14.jpg'}
#
#
# {'Nombre': ' Perea i Conillas,  María Mercè ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/203_14.jpg'}
#
#
# {'Nombre': ' Guinart Moreno,  Lídia ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/202_14.jpg'}
#
#
# {'Nombre': ' González Pérez,  Ariagona ', 'Territorio': 'Diputada por Palmas (Las)', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/164_14.jpg'}
#
#
# {'Nombre': ' Durán Peralta,  José Carlos ', 'Territorio': 'Diputado por Málaga', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/342_14.jpg'}
#
#
# {'Nombre': ' Ramón Utrabo,  Elvira ', 'Territorio': 'Diputada por Granada', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/8_14.jpg'}
#
#
# {'Nombre': ' Pons Sampietro,  Pere Joan ', 'Territorio': 'Diputado por Balears (Illes)', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/223_14.jpg'}
#
#
# {'Nombre': ' Sánchez Escobar,  Mariano ', 'Territorio': 'Diputado por Badajoz', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/227_14.jpg'}
#
#
# {'Nombre': ' Raya Rodríguez,  María Tamara ', 'Territorio': 'Diputada por S/C Tenerife', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/112_14.jpg'}
#
#
# {'Nombre': ' Ferrer Tesoro,  Sonia ', 'Territorio': 'Diputada por Almería', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/114_14.jpg'}
#
#
# {'Nombre': ' Villagrasa Quero,  Noemí ', 'Territorio': 'Diputada por Zaragoza', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/49_14.jpg'}
#
#
# {'Nombre': ' Ramos Rodríguez,  José Luis ', 'Territorio': 'Diputado por Huelva', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/218_14.jpg'}
#
#
# {'Nombre': ' Hurtado Zurera,  Antonio ', 'Territorio': 'Diputado por Córdoba', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/372_14.jpg'}
#
#
# {'Nombre': ' Narváez Bandera,  María Dolores ', 'Territorio': 'Diputada por Málaga', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/154_14.jpg'}
#
#
# {'Nombre': ' Bel Accensi,  Ferran ', 'Territorio': 'Diputado por Tarragona', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/14_14.jpg'}
#
#
# {'Nombre': ' Nogueras i Camero,  Míriam ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/27_14.jpg'}
#
#
# {'Nombre': ' Borràs Castanyer,  Laura ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/25_14.jpg'}
#
#
# {'Nombre': ' Ramírez Carner,  Arnau ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/197_14.jpg'}
#
#
# {'Nombre': ' Aranda Vargas,  Francisco ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/198_14.jpg'}
#
#
# {'Nombre': ' Andrés Añón,  Carmen ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/204_14.jpg'}
#
#
# {'Nombre': ' Guaita Esteruelas,  Sandra ', 'Territorio': 'Diputada por Tarragona', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/208_14.jpg'}
#
#
# {'Nombre': ' José Vélez,  Rafael ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/361_14.jpg'}
#
#
# {'Nombre': ' Del Valle de Iscar,  Julio ', 'Territorio': 'Diputado por Valladolid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/360_14.jpg'}
#
#
# {'Nombre': ' Fernández Benéitez,  Andrea ', 'Territorio': 'Diputada por León', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/102_14.jpg'}
#
#
# {'Nombre': ' Antón Cacho,  Javier ', 'Territorio': 'Diputado por Soria', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/100_14.jpg'}
#
#
# {'Nombre': ' Arribas Maroto,  Manuel ', 'Territorio': 'Diputado por Ávila', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/369_14.jpg'}
#
#
# {'Nombre': ' Ortega Domínguez,  José Ramón ', 'Territorio': 'Diputado por Cádiz', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/368_14.jpg'}
#
#
# {'Nombre': ' Oria López,  María Inmaculada ', 'Territorio': 'Diputada por Granada', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/370_14.jpg'}
#
#
# {'Nombre': ' Losada Fernández,  José ', 'Territorio': 'Diputado por Sevilla', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/353_14.jpg'}
#
#
# {'Nombre': ' Lima Cid,  Fuensanta ', 'Territorio': 'Diputada por Málaga', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/59_14.jpg'}
#
#
# {'Nombre': ' Araujo Morales,  Gemma ', 'Territorio': 'Diputada por Cádiz', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/364_14.jpg'}
#
#
# {'Nombre': ' Rodríguez Gómez,  María del Pilar ', 'Territorio': 'Diputada por Huelva', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/273_14.jpg'}
#
#
# {'Nombre': ' Boadella Esteve,  Genís ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/24_14.jpg'}
#
#
# {'Nombre': ' Alonso-Cuevillas i Sayrol,  Jaume ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/26_14.jpg'}
#
#
# {'Nombre': ' Illamola Dausà,  Mariona ', 'Territorio': 'Diputada por Girona', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/22_14.jpg'}
#
#
# {'Nombre': ' Cañadell Salvia,  Concep ', 'Territorio': 'Diputada por Lleida', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/21_14.jpg'}
#
#
# {'Nombre': ' Miquel i Valentí,  Sergi ', 'Territorio': 'Diputado por Girona', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/23_14.jpg'}
#
#
# {'Nombre': ' Asens Llodrà,  Jaume ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/291_14.jpg'}
#
#
# {'Nombre': ' Fernández Castañón,  Sofía ', 'Territorio': 'Diputada por Asturias', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/272_14.jpg'}
#
#
# {'Nombre': ' Santiago Romero,  Enrique Fernando ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/45_14.jpg'}
#
#
# {'Nombre': ' Gómez-Reino Varela,  Antonio ', 'Territorio': 'Diputado por Coruña (A)', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/176_14.jpg'}
#
#
# {'Nombre': ' Sagastizabal Unzetabarrenetxea,  Idoia ', 'Territorio': 'Diputada por Bizkaia', 'Partido': ' G. P. Vasco (EAJ-PNV) ', 'Foto': '/docu/imgweb/diputados/98_14.jpg'}
#
#
# {'Nombre': ' Legarda Uriarte,  Mikel ', 'Territorio': 'Diputado por Araba/Álava', 'Partido': ' G. P. Vasco (EAJ-PNV) ', 'Foto': '/docu/imgweb/diputados/95_14.jpg'}
#
#
# {'Nombre': ' Esteban Bravo,  Aitor ', 'Territorio': 'Diputado por Bizkaia', 'Partido': ' G. P. Vasco (EAJ-PNV) ', 'Foto': '/docu/imgweb/diputados/94_14.jpg'}
#
#
# {'Nombre': ' Mayoral Perales,  Rafael ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/336_14.jpg'}
#
#
# {'Nombre': ' Rodríguez Rodríguez,  Alberto ', 'Territorio': 'Diputado por S/C Tenerife', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/338_14.jpg'}
#
#
# {'Nombre': ' Belarra Urteaga,  Ione ', 'Territorio': 'Diputada por Navarra', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/139_14.jpg'}
#
#
# {'Nombre': ' Vera Ruíz-Herrera,  Noelia ', 'Territorio': 'Diputada por Cádiz', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/345_14.jpg'}
#
#
# {'Nombre': ' Garrido Gutiérrez,  Pilar ', 'Territorio': 'Diputada por Gipuzkoa', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/210_14.jpg'}
#
#
# {'Nombre': ' García Puig,  María del Mar ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/265_14.jpg'}
#
#
# {'Nombre': ' Mena Arca,  Joan ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/264_14.jpg'}
#
#
# {'Nombre': ' Gorospe Elezcano,  Josune ', 'Territorio': 'Diputada por Bizkaia', 'Partido': ' G. P. Vasco (EAJ-PNV) ', 'Foto': '/docu/imgweb/diputados/96_14.jpg'}
#
#
# {'Nombre': ' Barandiaran Benito,  Íñigo ', 'Territorio': 'Diputado por Gipuzkoa', 'Partido': ' G. P. Vasco (EAJ-PNV) ', 'Foto': '/docu/imgweb/diputados/97_14.jpg'}
#
#
# {'Nombre': ' Agirretxea Urresti,  Joseba Andoni ', 'Territorio': 'Diputado por Gipuzkoa', 'Partido': ' G. P. Vasco (EAJ-PNV) ', 'Foto': '/docu/imgweb/diputados/99_14.jpg'}
#
#
# {'Nombre': ' Guijarro García,  Txema ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/344_14.jpg'}
#
#
# {'Nombre': ' Pita Cárdenes,  María del Carmen ', 'Territorio': 'Diputada por Palmas (Las)', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/356_14.jpg'}
#
#
# {'Nombre': ' Maestro Moliner,  Roser ', 'Territorio': 'Diputada por Valencia/València', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/282_14.jpg'}
#
#
# {'Nombre': ' López Domínguez,  Laura ', 'Territorio': 'Diputada por Girona', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/263_14.jpg'}
#
#
# {'Nombre': ' Cortés Gómez,  Ismael ', 'Territorio': 'Diputado por Tarragona', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/350_14.jpg'}
#
#
# {'Nombre': ' Vidal Sáez,  Aina ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/266_14.jpg'}
#
#
# {'Nombre': ' Carvalho Dantas,  María ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/190_14.jpg'}
#
#
# {'Nombre': ' Eritja Ciuró,  Francesc Xavier ', 'Territorio': 'Diputado por Lleida', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/186_14.jpg'}
#
#
# {'Nombre': ' Salvador i Duch,  Jordi ', 'Territorio': 'Diputado por Tarragona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/184_14.jpg'}
#
#
# {'Nombre': ' Bassa Coll,  Montserrat ', 'Territorio': 'Diputada por Girona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/192_14.jpg'}
#
#
# {'Nombre': ' Telechea i Lozano,  Carolina ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/188_14.jpg'}
#
#
# {'Nombre': ' Rufián Romero,  Gabriel ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/187_14.jpg'}
#
#
# {'Nombre': ' López de Uralde Garmendia,  Juan Antonio ', 'Territorio': 'Diputado por Araba/Álava', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/205_14.jpg'}
#
#
# {'Nombre': ' Uriarte Torrealday,  Roberto ', 'Territorio': 'Diputado por Bizkaia', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/207_14.jpg'}
#
#
# {'Nombre': ' Franco Carmona,  Isabel ', 'Territorio': 'Diputada por Sevilla', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/321_14.jpg'}
#
#
# {'Nombre': ' Velarde Gómez,  Martina ', 'Territorio': 'Diputada por Córdoba', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/235_14.jpg'}
#
#
# {'Nombre': ' Márquez Guerrero,  María ', 'Territorio': 'Diputada por Sevilla', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/236_14.jpg'}
#
#
# {'Nombre': ' Honrubia Hurtado,  Pedro Antonio ', 'Territorio': 'Diputado por Granada', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/68_14.jpg'}
#
#
# {'Nombre': ' Jover Díaz,  Antonia ', 'Territorio': 'Diputada por Balears (Illes)', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/334_14.jpg'}
#
#
# {'Nombre': ' Muñoz Dalda,  Lucía ', 'Territorio': 'Diputada por Balears (Illes)', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/335_14.jpg'}
#
#
# {'Nombre': ' Capdevila i Esteve,  Joan ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/172_14.jpg'}
#
#
# {'Nombre': ' Vallugera Balañà,  Pilar ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/88_14.jpg'}
#
#
# {'Nombre': ' Granollers Cunillera,  Inés ', 'Territorio': 'Diputada por Lleida', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/183_14.jpg'}
#
#
# {'Nombre': ' Pujol i Farré,  Norma ', 'Territorio': 'Diputada por Tarragona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/191_14.jpg'}
#
#
# {'Nombre': ' Margall Sastre,  Joan ', 'Territorio': 'Diputado por Girona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/193_14.jpg'}
#
#
# {'Nombre': ' Rosique i Saltor,  Marta ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/185_14.jpg'}
#
#
# {'Nombre': ' Nuet Pujals,  Joan Josep ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Republicano ', 'Foto': '/docu/imgweb/diputados/189_14.jpg'}
#
#
# {'Nombre': ' Saavedra Muñoz,  Marisa ', 'Territorio': 'Diputada por Castellón/Castelló', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/348_14.jpg'}
#
#
# {'Nombre': ' Medel Pérez,  Rosa María ', 'Territorio': 'Diputada por Valencia/València', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/355_14.jpg'}
#
#
# {'Nombre': ' Aizpurua Arzallus,  Mertxe ', 'Territorio': 'Diputada por Gipuzkoa', 'Partido': ' G. P. EH Bildu ', 'Foto': '/docu/imgweb/diputados/69_14.jpg'}
#
#
# {'Nombre': ' Matute García de Jalón,  Oskar ', 'Territorio': 'Diputado por Bizkaia', 'Partido': ' G. P. EH Bildu ', 'Foto': '/docu/imgweb/diputados/63_14.jpg'}
#
#
# {'Nombre': ' Pozueta Fernández,  Isabel ', 'Territorio': 'Diputada por Navarra', 'Partido': ' G. P. EH Bildu ', 'Foto': '/docu/imgweb/diputados/65_14.jpg'}
#
#
# {'Nombre': ' Botran Pahissa,  Albert ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Mixto ', 'Foto': '/docu/imgweb/diputados/87_14.jpg'}
#
#
# {'Nombre': ' Vehí Cantenys,  Mireia ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Mixto ', 'Foto': '/docu/imgweb/diputados/86_14.jpg'}
#
#
# {'Nombre': ' García Adanero,  Carlos ', 'Territorio': 'Diputado por Navarra', 'Partido': ' G. P. Mixto ', 'Foto': '/docu/imgweb/diputados/127_14.jpg'}
#
#
# {'Nombre': ' Sayas López,  Sergio ', 'Territorio': 'Diputado por Navarra', 'Partido': ' G. P. Mixto ', 'Foto': '/docu/imgweb/diputados/55_14.jpg'}
#
#
# {'Nombre': ' Sáez Alonso-Muñumer,  Pablo ', 'Territorio': 'Diputado por Valladolid', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/278_14.jpg'}
#
#
# {'Nombre': ' Fernández Hernández,  Pedro ', 'Territorio': 'Diputado por Zaragoza', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/146_14.jpg'}
#
#
# {'Nombre': ' González Coello de Portugal,  Víctor ', 'Territorio': 'Diputado por Salamanca', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/76_14.jpg'}
#
#
# {'Nombre': ' Ruiz Solás,  María de la Cabeza ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/301_14.jpg'}
#
#
# {'Nombre': ' López Maraver,  Ángel ', 'Territorio': 'Diputado por Guadalajara', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/311_14.jpg'}
#
#
# {'Nombre': ' Borrás Pabón,  Mireia ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/142_14.jpg'}
#
#
# {'Nombre': ' Rego Candamil,  Néstor ', 'Territorio': 'Diputado por Coruña (A)', 'Partido': ' G. P. Plural ', 'Foto': '/docu/imgweb/diputados/40_14.jpg'}
#
#
# {'Nombre': ' Iñarritu García,  Jon ', 'Territorio': 'Diputado por Gipuzkoa', 'Partido': ' G. P. EH Bildu ', 'Foto': '/docu/imgweb/diputados/62_14.jpg'}
#
#
# {'Nombre': ' Ruiz de Pinedo Undiano,  Iñaki ', 'Territorio': 'Diputado por Araba/Álava', 'Partido': ' G. P. EH Bildu ', 'Foto': '/docu/imgweb/diputados/64_14.jpg'}
#
#
# {'Nombre': ' Guitarte Gimeno,  Tomás ', 'Territorio': 'Diputado por Teruel', 'Partido': ' G. P. Mixto ', 'Foto': '/docu/imgweb/diputados/306_14.jpg'}
#
#
# {'Nombre': ' Mazón Ramos,  José María ', 'Territorio': 'Diputado por Cantabria', 'Partido': ' G. P. Mixto ', 'Foto': '/docu/imgweb/diputados/349_14.jpg'}
#
#
# {'Nombre': ' Jara Moreno,  Mercedes ', 'Territorio': 'Diputada por Almería', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/377_14.jpg'}
#
#
# {'Nombre': ' Jiménez Revuelta,  Rodrigo ', 'Territorio': 'Diputado por Segovia', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/165_14.jpg'}
#
#
# {'Nombre': ' Ramírez del Río,  José ', 'Territorio': 'Diputado por Córdoba', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/93_14.jpg'}
#
#
# {'Nombre': ' Trías Gil,  Georgina ', 'Territorio': 'Diputada por Ávila', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/277_14.jpg'}
#
#
# {'Nombre': ' Sánchez del Real,  Víctor Manuel ', 'Territorio': 'Diputado por Badajoz', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/195_14.jpg'}
#
#
# {'Nombre': ' Robles López,  Joaquín ', 'Territorio': 'Diputado por Murcia', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/246_14.jpg'}
#
#
# {'Nombre': ' Asarta Cuevas,  Alberto ', 'Territorio': 'Diputado por Castellón/Castelló', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/129_14.jpg'}
#
#
# {'Nombre': ' Toscano de Balbín,  Carla ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/296_14.jpg'}
#
#
# {'Nombre': ' Rosety Fernández de Castro,  Agustín ', 'Territorio': 'Diputado por Cádiz', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/255_14.jpg'}
#
#
# {'Nombre': ' Echenique Robba,  Pablo ', 'Territorio': 'Diputado por Zaragoza', 'Partido': ' G. P. Confederal de Unidas Podemos-En Comú Podem-Galicia en Común ', 'Foto': '/docu/imgweb/diputados/13_14.jpg'}
#
#
# {'Nombre': ' Oramas González-Moro,  Ana María ', 'Territorio': 'Diputada por S/C Tenerife', 'Partido': ' G. P. Mixto ', 'Foto': '/docu/imgweb/diputados/161_14.jpg'}
#
#
# {'Nombre': ' Quevedo Iturbe,  Pedro ', 'Territorio': 'Diputado por Palmas (Las)', 'Partido': ' G. P. Mixto ', 'Foto': '/docu/imgweb/diputados/351_14.jpg'}
#
#
# {'Nombre': ' Martínez Oblanca,  Isidro Manuel ', 'Territorio': 'Diputado por Asturias', 'Partido': ' G. P. Mixto ', 'Foto': '/docu/imgweb/diputados/20_14.jpg'}
#
#
# {'Nombre': ' Requejo Novoa,  Pedro Jesús ', 'Territorio': 'Diputado por Zamora', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/85_14.jpg'}
#
#
# {'Nombre': ' Salvá Verd,  Antonio ', 'Territorio': 'Diputado por Balears (Illes)', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/162_14.jpg'}
#
#
# {'Nombre': ' Calvo Liste,  Pablo Juan ', 'Territorio': 'Diputado por León', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/213_14.jpg'}
#
#
# {'Nombre': ' De las Heras Fernández,  Patricia ', 'Territorio': 'Diputada por Balears (Illes)', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/248_14.jpg'}
#
#
# {'Nombre': ' Zambrano García-Raez,  Carlos José ', 'Territorio': 'Diputado por Cádiz', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/254_14.jpg'}
#
#
# {'Nombre': ' Ruiz Navarro,  Eduardo Luis ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/217_14.jpg'}
#
#
# {'Nombre': ' Vega Arias,  Rubén Darío ', 'Territorio': 'Diputado por S/C Tenerife', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/271_14.jpg'}
#
#
# {'Nombre': ' Rodríguez Almeida,  Andrés Alberto ', 'Territorio': 'Diputado por Palmas (Las)', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/256_14.jpg'}
#
#
# {'Nombre': ' Fernández-Lomana Gutiérrez,  Rafael ', 'Territorio': 'Diputado por Albacete', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/294_14.jpg'}
#
#
# {'Nombre': ' Del Valle Rodríguez,  Emilio Jesús ', 'Territorio': 'Diputado por Cantabria', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/175_14.jpg'}
#
#
# {'Nombre': ' Contreras Peláez,  Francisco José ', 'Territorio': 'Diputado por Sevilla', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/229_14.jpg'}
#
#
# {'Nombre': ' Manso Olivar,  Rubén Silvano ', 'Territorio': 'Diputado por Málaga', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/119_14.jpg'}
#
#
# {'Nombre': ' Sánchez García,  José María ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/322_14.jpg'}
#
#
# {'Nombre': ' Abascal Conde,  Santiago ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/43_14.jpg'}
#
#
# {'Nombre': ' Espinosa de los Monteros de Simón,  Iván ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/83_14.jpg'}
#
#
# {'Nombre': ' Olona Choclán,  Macarena ', 'Territorio': 'Diputada por Granada', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/84_14.jpg'}
#
#
# {'Nombre': ' Montesinos de Miguel,  Macarena ', 'Territorio': 'Diputada por Alicante/Alacant', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/346_14.jpg'}
#
#
# {'Nombre': ' Echániz Salgado,  José Ignacio ', 'Territorio': 'Diputado por Guadalajara', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/89_14.jpg'}
#
#
# {'Nombre': ' Borrego Cortés,  Isabel María ', 'Territorio': 'Diputada por Murcia', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/130_14.jpg'}
#
#
# {'Nombre': ' Mariscal Anaya,  Guillermo ', 'Territorio': 'Diputado por Palmas (Las)', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/339_14.jpg'}
#
#
# {'Nombre': ' García Egea,  Teodoro ', 'Territorio': 'Diputado por Murcia', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/310_14.jpg'}
#
#
# {'Nombre': ' Gamarra Ruiz-Clavijo,  Concepción ', 'Territorio': 'Diputada por Rioja (La)', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/261_14.jpg'}
#
#
# {'Nombre': ' Casado Blanco,  Pablo ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/307_14.jpg'}
#
#
# {'Nombre': ' Ortega Smith-Molina,  Francisco Javier ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/326_14.jpg'}
#
#
# {'Nombre': ' Garriga Vaz de Concicao,  Ignacio ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/150_14.jpg'}
#
#
# {'Nombre': ' Rueda Perelló,  Patricia ', 'Territorio': 'Diputada por Málaga', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/75_14.jpg'}
#
#
# {'Nombre': ' De Meer Méndez,  Rocío ', 'Territorio': 'Diputada por Almería', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/340_14.jpg'}
#
#
# {'Nombre': ' Moneo Díez,  María Sandra ', 'Territorio': 'Diputada por Burgos', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/337_14.jpg'}
#
#
# {'Nombre': ' González Vázquez,  Marta ', 'Territorio': 'Diputada por Coruña (A)', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/237_14.jpg'}
#
#
# {'Nombre': ' Hispán Iglesias de Ussel,  Pablo ', 'Territorio': 'Diputado por Granada', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/309_14.jpg'}
#
#
# {'Nombre': ' Hoyo Juliá,  Belén ', 'Territorio': 'Diputada por Valencia/València', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/141_14.jpg'}
#
#
# {'Nombre': ' Olano Vela,  Jaime Eduardo de ', 'Territorio': 'Diputado por Lugo', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/167_14.jpg'}
#
#
# {'Nombre': ' Montesinos Aguayo,  Pablo ', 'Territorio': 'Diputado por Málaga', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/315_14.jpg'}
#
#
# {'Nombre': ' González Terol,  Antonio ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/166_14.jpg'}
#
#
# {'Nombre': ' Beltrán Villalba,  Ana María ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/260_14.jpg'}
#
#
# {'Nombre': ' Arrimadas García,  Inés ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Ciudadanos ', 'Foto': '/docu/imgweb/diputados/331_14.jpg'}
#
#
# {'Nombre': ' Bal Francés,  Edmundo ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Ciudadanos ', 'Foto': '/docu/imgweb/diputados/211_14.jpg'}
#
#
# {'Nombre': ' Espejo-Saavedra Conesa,  José María ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. Ciudadanos ', 'Foto': '/docu/imgweb/diputados/257_14.jpg'}
#
#
# {'Nombre': ' Figaredo Álvarez-Sala,  José María ', 'Territorio': 'Diputado por Asturias', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/318_14.jpg'}
#
#
# {'Nombre': ' Romero Vilches,  María de los Reyes ', 'Territorio': 'Diputada por Sevilla', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/174_14.jpg'}
#
#
# {'Nombre': ' Marcos Ortega,  Milagros ', 'Territorio': 'Diputada por Palencia', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/92_14.jpg'}
#
#
# {'Nombre': ' Sánchez Pérez,  César ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/249_14.jpg'}
#
#
# {'Nombre': ' Movellán Lombilla,  Diego ', 'Territorio': 'Diputado por Cantabria', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/78_14.jpg'}
#
#
# {'Nombre': ' Herrero Bono,  José Alberto ', 'Territorio': 'Diputado por Teruel', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/239_14.jpg'}
#
#
# {'Nombre': ' Betoret Coll,  Vicente ', 'Territorio': 'Diputado por Valencia/València', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/228_14.jpg'}
#
#
# {'Nombre': ' Casero Ávila,  Alberto ', 'Territorio': 'Diputado por Cáceres', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/283_14.jpg'}
#
#
# {'Nombre': ' Prohens Rigo,  Margarita ', 'Territorio': 'Diputada por Balears (Illes)', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/243_14.jpg'}
#
#
# {'Nombre': ' Garcés Sanagustín,  Mario ', 'Territorio': 'Diputado por Huesca', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/219_14.jpg'}
#
#
# {'Nombre': ' Rojas García,  Carlos ', 'Territorio': 'Diputado por Granada', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/242_14.jpg'}
#
#
# {'Nombre': ' Rodríguez Herrer,  María Elvira ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/123_14.jpg'}
#
#
# ...
#
#
# {'Nombre': ' Delgado Arce,  Celso Luis ', 'Territorio': 'Diputado por Ourense', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/116_14.jpg'}
#
#
# {'Nombre': ' Tirado Ochoa,  Vicente ', 'Territorio': 'Diputado por Toledo', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/16_14.jpg'}
#
#
# {'Nombre': ' Suárez Lamata,  Eloy ', 'Territorio': 'Diputado por Zaragoza', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/214_14.jpg'}
#
#
# {'Nombre': ' Bermúdez de Castro Fernández,  José Antonio ', 'Territorio': 'Diputado por Salamanca', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/181_14.jpg'}
#
#
# {'Nombre': ' Romero Sánchez,  Rosa María ', 'Territorio': 'Diputada por Ciudad Real', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/36_14.jpg'}
#
#
# {'Nombre': ' Gago Bugarín,  Diego ', 'Territorio': 'Diputado por Pontevedra', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/121_14.jpg'}
#
#
# {'Nombre': ' Vázquez Blanco,  Ana Belén ', 'Territorio': 'Diputada por Ourense', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/115_14.jpg'}
#
#
# {'Nombre': ' Martínez Ferro,  María Valentina ', 'Territorio': 'Diputada por Coruña (A)', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/341_14.jpg'}
#
#
# {'Nombre': ' Uriarte Bengoechea,  Edurne ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/30_14.jpg'}
#
#
# {'Nombre': ' Navarro Lacoba,  Carmen ', 'Territorio': 'Diputada por Albacete', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/82_14.jpg'}
#
#
# {'Nombre': ' Muñoz Vidal,  María ', 'Territorio': 'Diputada por Valencia/València', 'Partido': ' G. P. Ciudadanos ', 'Foto': '/docu/imgweb/diputados/333_14.jpg'}
#
#
# {'Nombre': ' Cambronero Piqueras,  Pablo ', 'Territorio': 'Diputado por Sevilla', 'Partido': ' G. P. Ciudadanos ', 'Foto': '/docu/imgweb/diputados/58_14.jpg'}
#
#
# {'Nombre': ' Giménez Giménez,  Sara ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Ciudadanos ', 'Foto': '/docu/imgweb/diputados/169_14.jpg'}
#
#
# {'Nombre': ' Martínez Granados,  María Carmen ', 'Territorio': 'Diputada por Cádiz', 'Partido': ' G. P. Ciudadanos ', 'Foto': '/docu/imgweb/diputados/60_14.jpg'}
#
#
# {'Nombre': ' López Álvarez,  María Teresa ', 'Territorio': 'Diputada por Ceuta', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/327_14.jpg'}
#
#
# {'Nombre': ' Fernández Ríos,  Tomás ', 'Territorio': 'Diputado por Huelva', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/330_14.jpg'}
#
#
# {'Nombre': ' Requena Ruiz,  Juan Diego ', 'Territorio': 'Diputado por Jaén', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/79_14.jpg'}
#
#
# {'Nombre': ' Gutiérrez Díaz de Otazu,  Fernando Adolfo ', 'Territorio': 'Diputado por Melilla', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/149_14.jpg'}
#
#
# {'Nombre': ' Elorriaga Pisarik,  Gabriel ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/376_14.jpg'}
#
#
# {'Nombre': ' Pedreño Molina,  Juan Luis ', 'Territorio': 'Diputado por Murcia', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/132_14.jpg'}
#
#
# {'Nombre': ' Castellón Rubio,  Miguel Ángel ', 'Territorio': 'Diputado por Almería', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/74_14.jpg'}
#
#
# {'Nombre': ' González Guinda,  María del Carmen ', 'Territorio': 'Diputada por León', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/288_14.jpg'}
#
#
# {'Nombre': ' García Rodríguez,  Alicia ', 'Territorio': 'Diputada por Ávila', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/50_14.jpg'}
#
#
# {'Nombre': ' Mateu Istúriz,  Jaime Miguel ', 'Territorio': 'Diputado por Burgos', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/133_14.jpg'}
#
#
# {'Nombre': ' Zurita Expósito,  Ana María ', 'Territorio': 'Diputada por S/C Tenerife', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/111_14.jpg'}
#
#
# {'Nombre': ' Aragonés Mendiguchía,  Carlos ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/232_14.jpg'}
#
#
# {'Nombre': ' Mestre Barea,  Manuel ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/268_14.jpg'}
#
#
# {'Nombre': ' Nevado del Campo,  María Magdalena ', 'Territorio': 'Diputada por Cáceres', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/293_14.jpg'}
#
#
# {'Nombre': ' Chamorro Delmo,  Ricardo ', 'Territorio': 'Diputado por Ciudad Real', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/125_14.jpg'}
#
#
# {'Nombre': ' Esteban Calonje,  Cristina Alicia ', 'Territorio': 'Diputada por Valencia/València', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/297_14.jpg'}
#
#
# {'Nombre': ' Utrilla Cano,  Julio ', 'Territorio': 'Diputado por Valencia/València', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/328_14.jpg'}
#
#
# {'Nombre': ' Santamaría Ruiz,  Luis ', 'Territorio': 'Diputado por Valencia/València', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/269_14.jpg'}
#
#
# {'Nombre': ' Almodóbar Barceló,  Agustín ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/305_14.jpg'}
#
#
# {'Nombre': ' Moraleja Gómez,  Tristana María ', 'Territorio': 'Diputada por Coruña (A)', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/57_14.jpg'}
#
#
# {'Nombre': ' Ortiz Galván,  José ', 'Territorio': 'Diputado por Cádiz', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/134_14.jpg'}
#
#
# {'Nombre': ' Angulo Romero,  María Teresa ', 'Territorio': 'Diputada por Badajoz', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/113_14.jpg'}
#
#
# {'Nombre': ' Marcos Domínguez,  Pilar ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/143_14.jpg'}
#
#
# {'Nombre': ' Clavell López,  Óscar ', 'Territorio': 'Diputado por Castellón/Castelló', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/108_14.jpg'}
#
#
# {'Nombre': ' Jiménez Linuesa,  Beatriz ', 'Territorio': 'Diputada por Cuenca', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/206_14.jpg'}
#
#
# {'Nombre': ' Lorite Lorite,  Andrés ', 'Territorio': 'Diputado por Córdoba', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/105_14.jpg'}
#
#
# {'Nombre': ' Píriz Maya,  Víctor Valentín ', 'Territorio': 'Diputado por Badajoz', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/9_14.jpg'}
#
#
# {'Nombre': ' España Reina,  Carolina ', 'Territorio': 'Diputada por Málaga', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/316_14.jpg'}
#
#
# {'Nombre': ' Steegmann Olmedillas,  Juan Luis ', 'Territorio': 'Diputado por Madrid', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/135_14.jpg'}
#
#
# {'Nombre': ' Aizcorbe Torra,  Juan José ', 'Territorio': 'Diputado por Barcelona', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/151_14.jpg'}
#
#
# {'Nombre': ' Cañizares Pacheco,  Inés María ', 'Territorio': 'Diputada por Toledo', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/152_14.jpg'}
#
#
# {'Nombre': ' Gestoso de Miguel,  Luis ', 'Territorio': 'Diputado por Murcia', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/131_14.jpg'}
#
#
# {'Nombre': ' Alcaraz Martos,  Francisco José ', 'Territorio': 'Diputado por Jaén', 'Partido': ' G. P. VOX ', 'Foto': '/docu/imgweb/diputados/252_14.jpg'}
#
#
# {'Nombre': ' Álvarez Fanjul,  Beatriz ', 'Territorio': 'Diputada por Bizkaia', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/101_14.jpg'}
#
#
# {'Nombre': ' Redondo Calvillo,  María de la O ', 'Territorio': 'Diputada por Córdoba', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/106_14.jpg'}
#
#
# {'Nombre': ' Postigo Quintana,  Jesús ', 'Territorio': 'Diputado por Segovia', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/51_14.jpg'}
#
#
# {'Nombre': ' Gamazo Micó,  Óscar ', 'Territorio': 'Diputado por Valencia/València', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/212_14.jpg'}
#
#
# {'Nombre': ' Cabezón Casas,  Tomás ', 'Territorio': 'Diputado por Soria', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/28_14.jpg'}
#
#
# {'Nombre': ' Gázquez Collado,  Paloma ', 'Territorio': 'Diputada por Asturias', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/279_14.jpg'}
#
#
# {'Nombre': ' Moro Almaraz,  María Jesús ', 'Territorio': 'Diputada por Salamanca', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/91_14.jpg'}
#
#
# {'Nombre': ' Navarro López,  Pedro ', 'Territorio': 'Diputado por Zaragoza', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/220_14.jpg'}
#
#
# {'Nombre': ' Velasco Morillo,  Elvira ', 'Territorio': 'Diputada por Zamora', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/10_14.jpg'}
#
#
# {'Nombre': ' Merino Martínez,  Javier ', 'Territorio': 'Diputado por Rioja (La)', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/138_14.jpg'}
#
#
# {'Nombre': ' Cruz-Guzmán García,  María Soledad ', 'Territorio': 'Diputada por Sevilla', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/159_14.jpg'}
#
#
# {'Nombre': ' De Luna Tobarra,  Llanos ', 'Territorio': 'Diputada por Barcelona', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/157_14.jpg'}
#
#
# {'Nombre': ' García Díez,  Joaquín María ', 'Territorio': 'Diputado por Lugo', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/11_14.jpg'}
#
#
# {'Nombre': ' Riolobos Regadera,  Carmen ', 'Territorio': 'Diputada por Toledo', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/7_14.jpg'}
#
#
# {'Nombre': ' Sancho Íñiguez,  Herminio Rufino ', 'Territorio': 'Diputado por Teruel', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/15_14.jpg'}
#
#
# {'Nombre': ' Tizón Vázquez,  Uxía ', 'Territorio': 'Diputada por Ourense', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/374_14.jpg'}
#
#
# {'Nombre': ' García Chavarría,  María Montserrat ', 'Territorio': 'Diputada por Coruña (A)', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/304_14.jpg'}
#
#
# {'Nombre': ' Vilches Ruiz,  María Luisa ', 'Territorio': 'Diputada por Albacete', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/332_14.jpg'}
#
#
# {'Nombre': ' González Caballero,  Miguel Ángel ', 'Territorio': 'Diputado por Ciudad Real', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/222_14.jpg'}
#
#
# {'Nombre': ' Canales Duque,  Mariana de Gracia ', 'Territorio': 'Diputada por Cuenca', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/3_14.jpg'}
#
#
# {'Nombre': ' Fuentes Curbelo,  Juan Bernardo ', 'Territorio': 'Diputado por Palmas (Las)', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/359_14.jpg'}
#
#
# {'Nombre': ' Cuatrecasas Asua,  Juan ', 'Territorio': 'Diputado por Rioja (La)', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/303_14.jpg'}
#
#
# {'Nombre': ' Cerqueiro González,  Javier ', 'Territorio': 'Diputado por Lugo', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/47_14.jpg'}
#
#
# {'Nombre': ' García López,  Maribel ', 'Territorio': 'Diputada por Badajoz', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/39_14.jpg'}
#
#
# {'Nombre': ' Padilla Ruiz,  Esther ', 'Territorio': 'Diputada por Toledo', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/173_14.jpg'}
#
#
# {'Nombre': ' López Zamora,  Cristina ', 'Territorio': 'Diputada por Ciudad Real', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/224_14.jpg'}
#
#
# {'Nombre': ' Senderos Oraá,  Daniel ', 'Territorio': 'Diputado por Araba/Álava', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/367_14.jpg'}
#
#
# {'Nombre': ' Pedraja Sáinz,  Raquel ', 'Territorio': 'Diputada por Rioja (La)', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/362_14.jpg'}
#
#
# {'Nombre': ' López Somoza,  Gema ', 'Territorio': 'Diputada por Madrid', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/363_14.jpg'}
#
#
# {'Nombre': ' Azorín Salar,  Lázaro ', 'Territorio': 'Diputado por Alicante/Alacant', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/371_14.jpg'}
#
#
# {'Nombre': ' Seva Ruiz,  Yolanda ', 'Territorio': 'Diputada por Alicante/Alacant', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/137_14.jpg'}
#
#
# {'Nombre': ' Sarrià Morell,  Vicent Manuel ', 'Territorio': 'Diputado por Valencia/València', 'Partido': ' G. P. Socialista ', 'Foto': '/docu/imgweb/diputados/90_14.jpg'}
#
#
# {'Nombre': ' Pérez Díaz,  María Auxiliadora ', 'Territorio': 'Diputada por Palmas (Las)', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/160_14.jpg'}
#
#
# {'Nombre': ' Callejas Cano,  Juan Antonio ', 'Territorio': 'Diputado por Ciudad Real', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/35_14.jpg'}
#
#
# {'Nombre': ' Carazo Hermoso,  Eduardo ', 'Territorio': 'Diputado por Valladolid', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/245_14.jpg'}
#
#
# {'Nombre': ' Alonso Pérez,  José Ángel ', 'Territorio': 'Diputado por Valladolid', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/244_14.jpg'}
#
#
# {'Nombre': ' Jiménez-Becerril Barrio,  María Teresa ', 'Territorio': 'Diputada por Sevilla', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/179_14.jpg'}
#
#
# {'Nombre': ' Paniagua Núñez,  Miguel Ángel ', 'Territorio': 'Diputado por Palencia', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/240_14.jpg'}
#
#
# {'Nombre': ' Ledesma Martín,  Sebastián Jesús ', 'Territorio': 'Diputado por S/C Tenerife', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/110_14.jpg'}
#
#
# {'Nombre': ' Castillo López,  Elena ', 'Territorio': 'Diputada por Cantabria', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/77_14.jpg'}
#
#
# {'Nombre': ' Bas Corugeira,  Javier ', 'Territorio': 'Diputado por Pontevedra', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/118_14.jpg'}
#
#
# {'Nombre': ' Jerez Juan,  Miguel Ángel ', 'Territorio': 'Diputado por Balears (Illes)', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/124_14.jpg'}
#
#
# {'Nombre': ' García-Pelayo Jurado,  María José ', 'Territorio': 'Diputada por Cádiz', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/17_14.jpg'}
#
#
# {'Nombre': ' Romero Hernández,  Carmelo ', 'Territorio': 'Diputado por Huelva', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/241_14.jpg'}
#
#
# {'Nombre': ' Cortés Carballo,  Mario ', 'Territorio': 'Diputado por Málaga', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/317_14.jpg'}
#
#
# {'Nombre': ' Ramallo Vázquez,  María Pilar ', 'Territorio': 'Diputada por Pontevedra', 'Partido': ' G. P. Popular en el Congreso ', 'Foto': '/docu/imgweb/diputados/117_14.jpg'}

# %% [markdown]
# ### Ejercicio opcional

# %% [markdown]
# Consultad la paǵina web de Open Notify, indicando la información sobre los humanos residentes fuera de la tierra (es decir, en el espacio). Dirección url en  [Open Notify](http://api.open-notify.org).
#
# Codificad una función que imprima por pantalla el número total de astronautas en el espacio, numero de naves tripuladas actualmente en órbita, así como el nombre de los astronautas que habitan para cada una de estas naves.
